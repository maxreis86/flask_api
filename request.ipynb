# %%
json_data = {'ACCNUM': -0.6902081234176572,
  'TIME': -1.7849563776094504,
  'WARDNUM': -0.013486367700859618,
  'LATITUDE': -0.1947000837086002,
  'LONGITUDE': 0.7396052389725251,
  'ROAD_CLASS_0': 0.0,
  'ROAD_CLASS_1': 0.0,
  'ROAD_CLASS_2': 0.0,
  'ROAD_CLASS_3': 0.0,
  'ROAD_CLASS_4': 0.0,
  'ROAD_CLASS_5': 1.0,
  'ROAD_CLASS_6': 0.0,
  'ROAD_CLASS_7': 0.0,
  'ROAD_CLASS_8': 0.0,
  'ROAD_CLASS_9': 0.0,
  'DISTRICT_0': 0.0,
  'DISTRICT_1': 0.0,
  'DISTRICT_2': 0.0,
  'DISTRICT_3': 1.0,
  'DISTRICT_4': 0.0,
  'DISTRICT_5': 0.0,
  'LOCCOORD_0': 0.0,
  'LOCCOORD_1': 0.0,
  'LOCCOORD_2': 0.0,
  'LOCCOORD_3': 1.0,
  'LOCCOORD_4': 0.0,
  'LOCCOORD_5': 0.0,
  'LOCCOORD_6': 0.0,
  'LOCCOORD_7': 0.0,
  'LOCCOORD_8': 0.0,
  'ACCLOC_0': 0.0,
  'ACCLOC_1': 0.0,
  'ACCLOC_2': 1.0,
  'ACCLOC_3': 0.0,
  'ACCLOC_4': 0.0,
  'ACCLOC_5': 0.0,
  'ACCLOC_6': 0.0,
  'ACCLOC_7': 0.0,
  'ACCLOC_8': 0.0,
  'ACCLOC_9': 0.0,
  'ACCLOC_10': 0.0,
  'TRAFFCTL_0': 1.0,
  'TRAFFCTL_1': 0.0,
  'TRAFFCTL_2': 0.0,
  'TRAFFCTL_3': 0.0,
  'TRAFFCTL_4': 0.0,
  'TRAFFCTL_5': 0.0,
  'TRAFFCTL_6': 0.0,
  'TRAFFCTL_7': 0.0,
  'TRAFFCTL_8': 0.0,
  'TRAFFCTL_9': 0.0,
  'TRAFFCTL_10': 0.0,
  'TRAFFCTL_11': 0.0,
  'VISIBILITY_0': 1.0,
  'VISIBILITY_1': 0.0,
  'VISIBILITY_2': 0.0,
  'VISIBILITY_3': 0.0,
  'VISIBILITY_4': 0.0,
  'VISIBILITY_5': 0.0,
  'VISIBILITY_6': 0.0,
  'VISIBILITY_7': 0.0,
  'VISIBILITY_8': 0.0,
  'LIGHT_0': 1.0,
  'LIGHT_1': 0.0,
  'LIGHT_2': 0.0,
  'LIGHT_3': 0.0,
  'LIGHT_4': 0.0,
  'LIGHT_5': 0.0,
  'LIGHT_6': 0.0,
  'LIGHT_7': 0.0,
  'LIGHT_8': 0.0,
  'LIGHT_9': 0.0,
  'RDSFCOND_0': 0.0,
  'RDSFCOND_1': 0.0,
  'RDSFCOND_2': 0.0,
  'RDSFCOND_3': 0.0,
  'RDSFCOND_4': 0.0,
  'RDSFCOND_5': 0.0,
  'RDSFCOND_6': 0.0,
  'RDSFCOND_7': 0.0,
  'RDSFCOND_8': 1.0,
  'RDSFCOND_9': 0.0,
  'IMPACTYPE_0': 0.0,
  'IMPACTYPE_1': 1.0,
  'IMPACTYPE_2': 0.0,
  'IMPACTYPE_3': 0.0,
  'IMPACTYPE_4': 0.0,
  'IMPACTYPE_5': 0.0,
  'IMPACTYPE_6': 0.0,
  'IMPACTYPE_7': 0.0,
  'IMPACTYPE_8': 0.0,
  'IMPACTYPE_9': 0.0,
  'IMPACTYPE_10': 0.0,
  'INVTYPE_0': 0.0,
  'INVTYPE_1': 0.0,
  'INVTYPE_2': 0.0,
  'INVTYPE_3': 0.0,
  'INVTYPE_4': 0.0,
  'INVTYPE_5': 0.0,
  'INVTYPE_6': 0.0,
  'INVTYPE_7': 0.0,
  'INVTYPE_8': 0.0,
  'INVTYPE_9': 0.0,
  'INVTYPE_10': 0.0,
  'INVTYPE_11': 1.0,
  'INVTYPE_12': 0.0,
  'INVTYPE_13': 0.0,
  'INVTYPE_14': 0.0,
  'INVTYPE_15': 0.0,
  'INVTYPE_16': 0.0,
  'INVTYPE_17': 0.0,
  'INVTYPE_18': 0.0,
  'INVTYPE_19': 0.0,
  'INVAGE_0': 0.0,
  'INVAGE_1': 0.0,
  'INVAGE_2': 0.0,
  'INVAGE_3': 0.0,
  'INVAGE_4': 0.0,
  'INVAGE_5': 0.0,
  'INVAGE_6': 0.0,
  'INVAGE_7': 0.0,
  'INVAGE_8': 0.0,
  'INVAGE_9': 0.0,
  'INVAGE_10': 1.0,
  'INVAGE_11': 0.0,
  'INVAGE_12': 0.0,
  'INVAGE_13': 0.0,
  'INVAGE_14': 0.0,
  'INVAGE_15': 0.0,
  'INVAGE_16': 0.0,
  'INVAGE_17': 0.0,
  'INVAGE_18': 0.0,
  'INVAGE_19': 0.0,
  'INVAGE_20': 0.0,
  'INVAGE_21': 0.0,
  'INJURY_0': 0.0,
  'INJURY_1': 1.0,
  'INJURY_2': 0.0,
  'INJURY_3': 0.0,
  'INJURY_4': 0.0,
  'INJURY_5': 0.0,
  'INJURY_6': 0.0,
  'INITDIR_0': 0.0,
  'INITDIR_1': 0.0,
  'INITDIR_2': 0.0,
  'INITDIR_3': 1.0,
  'INITDIR_4': 0.0,
  'INITDIR_5': 0.0,
  'VEHTYPE_0': 0.0,
  'VEHTYPE_1': 0.0,
  'VEHTYPE_2': 0.0,
  'VEHTYPE_3': 0.0,
  'VEHTYPE_4': 0.0,
  'VEHTYPE_5': 0.0,
  'VEHTYPE_6': 0.0,
  'VEHTYPE_7': 0.0,
  'VEHTYPE_8': 0.0,
  'VEHTYPE_9': 0.0,
  'VEHTYPE_10': 0.0,
  'VEHTYPE_11': 0.0,
  'VEHTYPE_12': 0.0,
  'VEHTYPE_13': 1.0,
  'VEHTYPE_14': 0.0,
  'VEHTYPE_15': 0.0,
  'VEHTYPE_16': 0.0,
  'VEHTYPE_17': 0.0,
  'VEHTYPE_18': 0.0,
  'VEHTYPE_19': 0.0,
  'VEHTYPE_20': 0.0,
  'VEHTYPE_21': 0.0,
  'VEHTYPE_22': 0.0,
  'VEHTYPE_23': 0.0,
  'VEHTYPE_24': 0.0,
  'VEHTYPE_25': 0.0,
  'VEHTYPE_26': 0.0,
  'VEHTYPE_27': 0.0,
  'VEHTYPE_28': 0.0,
  'VEHTYPE_29': 0.0,
  'VEHTYPE_30': 0.0,
  'MANOEUVER_0': 0.0,
  'MANOEUVER_1': 0.0,
  'MANOEUVER_2': 0.0,
  'MANOEUVER_3': 0.0,
  'MANOEUVER_4': 0.0,
  'MANOEUVER_5': 0.0,
  'MANOEUVER_6': 0.0,
  'MANOEUVER_7': 0.0,
  'MANOEUVER_8': 0.0,
  'MANOEUVER_9': 0.0,
  'MANOEUVER_10': 0.0,
  'MANOEUVER_11': 0.0,
  'MANOEUVER_12': 0.0,
  'MANOEUVER_13': 0.0,
  'MANOEUVER_14': 0.0,
  'MANOEUVER_15': 1.0,
  'MANOEUVER_16': 0.0,
  'DRIVACT_0': 0.0,
  'DRIVACT_1': 0.0,
  'DRIVACT_2': 0.0,
  'DRIVACT_3': 0.0,
  'DRIVACT_4': 0.0,
  'DRIVACT_5': 0.0,
  'DRIVACT_6': 0.0,
  'DRIVACT_7': 0.0,
  'DRIVACT_8': 0.0,
  'DRIVACT_9': 1.0,
  'DRIVACT_10': 0.0,
  'DRIVACT_11': 0.0,
  'DRIVACT_12': 0.0,
  'DRIVACT_13': 0.0,
  'DRIVCOND_0': 0.0,
  'DRIVCOND_1': 0.0,
  'DRIVCOND_2': 0.0,
  'DRIVCOND_3': 0.0,
  'DRIVCOND_4': 0.0,
  'DRIVCOND_5': 0.0,
  'DRIVCOND_6': 0.0,
  'DRIVCOND_7': 0.0,
  'DRIVCOND_8': 0.0,
  'DRIVCOND_9': 1.0,
  'DRIVCOND_10': 0.0,
  'PEDTYPE_0': 1.0,
  'PEDTYPE_1': 0.0,
  'PEDTYPE_2': 0.0,
  'PEDTYPE_3': 0.0,
  'PEDTYPE_4': 0.0,
  'PEDTYPE_5': 0.0,
  'PEDTYPE_6': 0.0,
  'PEDTYPE_7': 0.0,
  'PEDTYPE_8': 0.0,
  'PEDTYPE_9': 0.0,
  'PEDTYPE_10': 0.0,
  'PEDTYPE_11': 0.0,
  'PEDTYPE_12': 0.0,
  'PEDTYPE_13': 0.0,
  'PEDTYPE_14': 0.0,
  'PEDTYPE_15': 0.0,
  'PEDTYPE_16': 0.0,
  'PEDACT_0': 0.0,
  'PEDACT_1': 0.0,
  'PEDACT_2': 0.0,
  'PEDACT_3': 0.0,
  'PEDACT_4': 0.0,
  'PEDACT_5': 0.0,
  'PEDACT_6': 0.0,
  'PEDACT_7': 1.0,
  'PEDACT_8': 0.0,
  'PEDACT_9': 0.0,
  'PEDACT_10': 0.0,
  'PEDACT_11': 0.0,
  'PEDACT_12': 0.0,
  'PEDACT_13': 0.0,
  'PEDACT_14': 0.0,
  'PEDACT_15': 0.0,
  'PEDCOND_0': 0.0,
  'PEDCOND_1': 0.0,
  'PEDCOND_2': 0.0,
  'PEDCOND_3': 0.0,
  'PEDCOND_4': 0.0,
  'PEDCOND_5': 0.0,
  'PEDCOND_6': 0.0,
  'PEDCOND_7': 0.0,
  'PEDCOND_8': 0.0,
  'PEDCOND_9': 1.0,
  'PEDCOND_10': 0.0,
  'PEDESTRIAN_0': 1.0,
  'PEDESTRIAN_1': 0.0,
  'PEDESTRIAN_2': 0.0,
  'CYCLIST_0': 1.0,
  'CYCLIST_1': 0.0,
  'CYCLIST_2': 0.0,
  'AUTOMOBILE_0': 0.0,
  'AUTOMOBILE_1': 1.0,
  'AUTOMOBILE_2': 0.0,
  'MOTORCYCLE_0': 1.0,
  'MOTORCYCLE_1': 0.0,
  'MOTORCYCLE_2': 0.0,
  'TRUCK_0': 1.0,
  'TRUCK_1': 0.0,
  'TRUCK_2': 0.0,
  'TRSN_CITY_VEH_0': 1.0,
  'TRSN_CITY_VEH_1': 0.0,
  'TRSN_CITY_VEH_2': 0.0,
  'PASSENGER_0': 0.0,
  'PASSENGER_1': 1.0,
  'PASSENGER_2': 0.0,
  'SPEEDING_0': 0.0,
  'SPEEDING_1': 1.0,
  'SPEEDING_2': 0.0,
  'AG_DRIV_0': 0.0,
  'AG_DRIV_1': 1.0,
  'AG_DRIV_2': 0.0,
  'REDLIGHT_0': 1.0,
  'REDLIGHT_1': 0.0,
  'REDLIGHT_2': 0.0,
  'DIVISION_0': 0.0,
  'DIVISION_1': 0.0,
  'DIVISION_2': 0.0,
  'DIVISION_3': 0.0,
  'DIVISION_4': 0.0,
  'DIVISION_5': 0.0,
  'DIVISION_6': 0.0,
  'DIVISION_7': 0.0,
  'DIVISION_8': 0.0,
  'DIVISION_9': 0.0,
  'DIVISION_10': 0.0,
  'DIVISION_11': 0.0,
  'DIVISION_12': 0.0,
  'DIVISION_13': 0.0,
  'DIVISION_14': 0.0,
  'DIVISION_15': 1.0,
  'DIVISION_16': 0.0,
  'DIVISION_17': 0.0}

# %%
import requests
url = 'http://localhost:5000/predict'
r = requests.post(url, json=json_data)
print(r.json())
